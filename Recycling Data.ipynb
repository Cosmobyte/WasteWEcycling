# %%
import pandas as pd

# %%
try:
    rc = pd.read_csv('recycling.csv')
except FileNotFoundError:
    print("99 problems")
else:
    rc = pd.read_csv('recycling.csv')

# %%
rc
# Out:
#                         Key    Product category   Municipality  \
# 0                       NaN                 NaN            NaN
# 1                   Acetone  Contains chemicals  Frederiksberg
# 2           Descaling Agent  Contains chemicals  Frederiksberg
# 3             Drain Cleaner  Contains chemicals  Frederiksberg
# 4                       NaN                 NaN            NaN
# ..                      ...                 ...            ...
# 395  Drinking cans, no pant               Metal  Frederiksberg
# 396                     NaN                 NaN            NaN
# 397                     NaN                 NaN            NaN
# 398                     NaN                 NaN            NaN
# 399                     NaN                 NaN            NaN
#
#       Waste category  Description
# 0                NaN          NaN
# 1    hazardous waste          NaN
# 2    hazardous waste          NaN
# 3    hazardous waste          NaN
# ...

# %%
rc.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 400 entries, 0 to 399
# Data columns (total 5 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Key               364 non-null    object
#  1   Product category  353 non-null    object
#  2   Municipality      365 non-null    object
#  3   Waste category    364 non-null    object
#  4   Description       0 non-null      float64
# dtypes: float64(1), object(4)
# memory usage: 15.8+ KB

# %%
rc.drop("Description", axis = 1, inplace = True)

# %%
rc
# Out:
#                         Key    Product category   Municipality  \
# 0                       NaN                 NaN            NaN
# 1                   Acetone  Contains chemicals  Frederiksberg
# 2           Descaling Agent  Contains chemicals  Frederiksberg
# 3             Drain Cleaner  Contains chemicals  Frederiksberg
# 4                       NaN                 NaN            NaN
# ..                      ...                 ...            ...
# 395  Drinking cans, no pant               Metal  Frederiksberg
# 396                     NaN                 NaN            NaN
# 397                     NaN                 NaN            NaN
# 398                     NaN                 NaN            NaN
# 399                     NaN                 NaN            NaN
#
#       Waste category
# 0                NaN
# 1    hazardous waste
# 2    hazardous waste
# 3    hazardous waste
# 4                NaN
# ..               ...
# 395            metal
# 396              NaN
# ...

# %%
rc.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 400 entries, 0 to 399
# Data columns (total 4 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Key               364 non-null    object
#  1   Product category  353 non-null    object
#  2   Municipality      365 non-null    object
#  3   Waste category    364 non-null    object
# dtypes: object(4)
# memory usage: 12.6+ KB

# %%
rc.dropna(inplace = True)

# %%
rc
# Out:
#                              Key        Product category   Municipality  \
# 1                        Acetone      Contains chemicals  Frederiksberg
# 2                Descaling Agent      Contains chemicals  Frederiksberg
# 3                  Drain Cleaner      Contains chemicals  Frederiksberg
# 5               Acrylic, plastic                 Plastic  Frederiksberg
# 6                Aquarium gravel                   Other  Frederiksberg
# ..                           ...                     ...            ...
# 388                   Yogurt cup  Food and Drink Cartons  Frederiksberg
# 389                Yogurt carton  Food and Drink Cartons  Frederiksberg
# 392  Egg trays, clean, cardboard       Paper & Cardboard  Frederiksberg
# 393    Egg trays, clean, plastic                 Plastic  Frederiksberg
# 395       Drinking cans, no pant                   Metal  Frederiksberg
#
#              Waste category
# 1           hazardous waste
# 2           hazardous waste
# ...

# %%
rc["Key"] = rc["Key"].str.lower()
rc["Product category"] = rc["Product category"].str.lower()
rc["Municipality"] = rc["Municipality"].str.lower()
rc["Waste category"] = rc["Waste category"].str.lower()

# %%
rc
# Out:
#                              Key        Product category   Municipality  \
# 1                        acetone      contains chemicals  frederiksberg
# 2                descaling agent      contains chemicals  frederiksberg
# 3                  drain cleaner      contains chemicals  frederiksberg
# 5               acrylic, plastic                 plastic  frederiksberg
# 6                aquarium gravel                   other  frederiksberg
# ..                           ...                     ...            ...
# 388                   yogurt cup  food and drink cartons  frederiksberg
# 389                yogurt carton  food and drink cartons  frederiksberg
# 392  egg trays, clean, cardboard       paper & cardboard  frederiksberg
# 393    egg trays, clean, plastic                 plastic  frederiksberg
# 395       drinking cans, no pant                   metal  frederiksberg
#
#              Waste category
# 1           hazardous waste
# 2           hazardous waste
# ...

# %%
rc["Product category"] = rc["Product category"].str.replace("and","&")
rc["Waste category"] = rc["Waste category"].str.replace("and","&")
rc["Key"] = rc["Key"].str.replace("and","&")
rc["Waste category"] = rc["Waste category"].str.replace("gass","glass")

# %%
rc
# Out:
#                              Key      Product category   Municipality  \
# 1                        acetone    contains chemicals  frederiksberg
# 2                descaling agent    contains chemicals  frederiksberg
# 3                  drain cleaner    contains chemicals  frederiksberg
# 5               acrylic, plastic               plastic  frederiksberg
# 6                aquarium gravel                 other  frederiksberg
# ..                           ...                   ...            ...
# 388                   yogurt cup  food & drink cartons  frederiksberg
# 389                yogurt carton  food & drink cartons  frederiksberg
# 392  egg trays, clean, cardboard     paper & cardboard  frederiksberg
# 393    egg trays, clean, plastic               plastic  frederiksberg
# 395       drinking cans, no pant                 metal  frederiksberg
#
#            Waste category
# 1         hazardous waste
# 2         hazardous waste
# 3         hazardous waste
# ...

# %%
rc["Waste category"].value_counts().plot.bar()
# Out:
# <AxesSubplot:>

# %%
rc["Waste category"].value_counts()
# Out:
# hazardous waste         74
# general waste           68
# electronics             37
# metal                   24
# plastic                 24
# bulky waste             21
# recycling center        19
# pvc                     18
# food waste              17
# paper                   11
# cardboard                9
# electronic               8
# recyling center          6
# garden waste             6
# food & drink cartons     5
# glass                    4
# pharmacy                 2
# Name: Waste category, dtype: int64

# %%
df = rc["Waste category"].value_counts()

# %%
df = df.to_frame()

# %%
df
# Out:
#                       Waste category
# hazardous waste                   74
# general waste                     68
# electronics                       37
# metal                             24
# plastic                           24
# bulky waste                       21
# recycling center                  19
# pvc                               18
# food waste                        17
# paper                             11
# cardboard                          9
# electronic                         8
# recyling center                    6
# garden waste                       6
# food & drink cartons               5
# glass                              4
# pharmacy                           2

# %%
import matplotlib.pyplot as plt

# %%
df.plot(kind="pie",y="Waste category", autopct='%1.1f%%',)
fig = plt.gcf()
fig.set_size_inches(12,12)
plt.show()
